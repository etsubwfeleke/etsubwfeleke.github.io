# %% [markdown]
# ### Mini-Project: Your First Digit-Reading AI
#
# **Goal:** Build, train, and test a complete Convolutional Neural Network (CNN) that can learn to recognize handwritten digits.

# %%
from torch.nn import Flatten
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, random_split, DataLoader
import os
from PIL import Image
import torchvision.transforms as transforms
from torchvision import datasets, transforms

# %% [markdown]
# ### Data Preprocessing and Splitting
#
# This cell applies transformations to the dataset, including normalization and grayscale conversion, and splits the data into training, validation, and test sets. It also creates data loaders for efficient batch processing during training and evaluation.

# %%
transformer_recipe = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize(mean=[0.1307], std=[0.3081]),
    transforms.Grayscale()
])
root_dir = datasets.ImageFolder(root='/Users/etsubfeleke/Documents/Pytorch_practice/MINST/minst_training', transform=transformer_recipe)
train_size = int(0.7 * len(root_dir))
val_size = int(0.1 * len(root_dir))
test_size = len(root_dir) - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(root_dir, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
class CNNBlock(nn.Module):
    def __init__(self, num_classes=10):
        super(CNNBlock, self).__init__()
        self.cnn = nn.Conv2d(in_channels=1,out_channels=16, kernel_size=5, stride=1, padding=2)
        self.relu = nn.ReLU()
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.cnn2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.relu2 = nn.ReLU()
        self.max_pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.fc1 = nn.Linear(32 * 7 * 7,  128)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(128, num_classes)
    def forward (self, x):
        x = self.cnn(x)
        x = self.relu(x)
        x = self.max_pool(x)
        x = self.cnn2(x)
        x = self.relu2(x)
        x= self.max_pool2(x)
        x= x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.relu3(x)
        x= self.fc2(x)
        return x

my_model = CNNBlock(num_classes=10)


ce_loss = nn.CrossEntropyLoss()
optimizer_sgd = optim.SGD(my_model.parameters(), lr=0.001)
batch_size = 64
num_epochs = 25
print(f"Layers: \n {my_model}")
# Out:
# Layers:
#  CNNBlock(
#   (cnn): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (relu): ReLU()
#   (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (cnn2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (relu2): ReLU()
#   (max_pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1568, out_features=128, bias=True)
#   (relu3): ReLU()
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# - **This script trains a neural network with early stopping to prevent overfitting.**
# - **It monitors training and validation loss each epoch to prevent overfitting.**
# - **Training stops automatically if validation loss doesn't improve for a set number of epochs (patience).**

# %% [markdown]
# **different epochs and batch sizes are used to see how they affect the model's performance.**
# --- Epoch [20/20],  Batch: [656], Loss: 0.3238
# ----  Test Accuracy: 96.381%
#
# --- Epoch [15/15],  Batch: [656], Loss: 0.0296
# ----  Test Accuracy: 95.357%
#
# --- Epoch [10/10],  Batch: [656], Loss: 0.3713
# ----  Test Accuracy: 92.881%
#
# --- Epoch [5/5],  Batch: [656], Loss: 0.1728
# ----  Test Accuracy: 89.762%

# %%
# Define the patience for early stopping
patience = 5
best_val_loss = float('inf')
epochs_no_improve = 0
num_epochs = 100  # Maximum number of epochs

for epoch in range(num_epochs):
    # Training loop
    my_model.train()
    train_loss = 0
    for images, labels in train_loader:
        outputs = my_model(images)
        loss = ce_loss(outputs, labels)
        
        optimizer_sgd.zero_grad()
        loss.backward()
        optimizer_sgd.step()
        
        train_loss += loss.item()
    
    train_loss /= len(train_loader)
    
    # Validation loop
    my_model.eval()
    val_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            outputs = my_model(images)
            loss = ce_loss(outputs, labels)
            val_loss += loss.item()
            
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    val_loss /= len(val_loader)
    accuracy = 100 * correct / total
    
    print(f"Epoch [{epoch+1}], Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Accuracy: {accuracy:.2f}%")
    
    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1
    
    if epochs_no_improve >= patience:
        print("Early stopping triggered.")
        break
# Out:
# Epoch [1], Train Loss: 2.2586, Val Loss: 2.1920, Accuracy: 54.14%
# Epoch [2], Train Loss: 2.0360, Val Loss: 1.7858, Accuracy: 71.38%
# Epoch [3], Train Loss: 1.3054, Val Loss: 0.8610, Accuracy: 80.57%
# Epoch [4], Train Loss: 0.6513, Val Loss: 0.5175, Accuracy: 86.29%
# Epoch [5], Train Loss: 0.4544, Val Loss: 0.3955, Accuracy: 89.45%
# Epoch [6], Train Loss: 0.3769, Val Loss: 0.3365, Accuracy: 90.71%
# Epoch [7], Train Loss: 0.3329, Val Loss: 0.3037, Accuracy: 91.50%
# Epoch [8], Train Loss: 0.3029, Val Loss: 0.2763, Accuracy: 92.05%
# Epoch [9], Train Loss: 0.2798, Val Loss: 0.2583, Accuracy: 92.40%
# Epoch [10], Train Loss: 0.2606, Val Loss: 0.2404, Accuracy: 93.02%
# Epoch [11], Train Loss: 0.2446, Val Loss: 0.2245, Accuracy: 93.29%
# Epoch [12], Train Loss: 0.2298, Val Loss: 0.2137, Accuracy: 93.88%
# Epoch [13], Train Loss: 0.2171, Val Loss: 0.2015, Accuracy: 94.21%
# Epoch [14], Train Loss: 0.2058, Val Loss: 0.1899, Accuracy: 94.48%
# Epoch [15], Train Loss: 0.1954, Val Loss: 0.1824, Accuracy: 94.83%
# Epoch [16], Train Loss: 0.1870, Val Loss: 0.1731, Accuracy: 95.07%
# Epoch [17], Train Loss: 0.1782, Val Loss: 0.1668, Accuracy: 95.02%
# Epoch [18], Train Loss: 0.1703, Val Loss: 0.1577, Accuracy: 95.33%
# Epoch [19], Train Loss: 0.1630, Val Loss: 0.1517, Accuracy: 95.69%
# Epoch [20], Train Loss: 0.1570, Val Loss: 0.1509, Accuracy: 95.60%
# Epoch [21], Train Loss: 0.1505, Val Loss: 0.1422, Accuracy: 95.62%
# Epoch [22], Train Loss: 0.1448, Val Loss: 0.1363, Accuracy: 96.05%
# Epoch [23], Train Loss: 0.1394, Val Loss: 0.1309, Accuracy: 96.10%
# Epoch [24], Train Loss: 0.1343, Val Loss: 0.1268, Accuracy: 96.33%
# Epoch [25], Train Loss: 0.1301, Val Loss: 0.1238, Accuracy: 96.36%
# Epoch [26], Train Loss: 0.1257, Val Loss: 0.1188, Accuracy: 96.40%
# Epoch [27], Train Loss: 0.1223, Val Loss: 0.1160, Accuracy: 96.50%
# Epoch [28], Train Loss: 0.1179, Val Loss: 0.1112, Accuracy: 96.57%
# Epoch [29], Train Loss: 0.1145, Val Loss: 0.1087, Accuracy: 96.71%
# Epoch [30], Train Loss: 0.1113, Val Loss: 0.1044, Accuracy: 96.83%
# Epoch [31], Train Loss: 0.1085, Val Loss: 0.1030, Accuracy: 96.76%
# Epoch [32], Train Loss: 0.1051, Val Loss: 0.1020, Accuracy: 97.00%
# Epoch [33], Train Loss: 0.1026, Val Loss: 0.0966, Accuracy: 96.98%
# Epoch [34], Train Loss: 0.1003, Val Loss: 0.0947, Accuracy: 97.05%
# Epoch [35], Train Loss: 0.0975, Val Loss: 0.0931, Accuracy: 97.17%
# Epoch [36], Train Loss: 0.0953, Val Loss: 0.0946, Accuracy: 97.07%
# Epoch [37], Train Loss: 0.0935, Val Loss: 0.0927, Accuracy: 97.17%
# Epoch [38], Train Loss: 0.0915, Val Loss: 0.0892, Accuracy: 97.36%
# Epoch [39], Train Loss: 0.0890, Val Loss: 0.0871, Accuracy: 97.21%
# Epoch [40], Train Loss: 0.0872, Val Loss: 0.0849, Accuracy: 97.38%
# Epoch [41], Train Loss: 0.0854, Val Loss: 0.0832, Accuracy: 97.29%
# Epoch [42], Train Loss: 0.0842, Val Loss: 0.0853, Accuracy: 97.48%
# Epoch [43], Train Loss: 0.0820, Val Loss: 0.0839, Accuracy: 97.43%
# Epoch [44], Train Loss: 0.0808, Val Loss: 0.0891, Accuracy: 97.33%
# Epoch [45], Train Loss: 0.0794, Val Loss: 0.0829, Accuracy: 97.40%
# Epoch [46], Train Loss: 0.0776, Val Loss: 0.0766, Accuracy: 97.55%
# Epoch [47], Train Loss: 0.0764, Val Loss: 0.0757, Accuracy: 97.57%
# Epoch [48], Train Loss: 0.0750, Val Loss: 0.0750, Accuracy: 97.64%
# Epoch [49], Train Loss: 0.0736, Val Loss: 0.0741, Accuracy: 97.57%
# Epoch [50], Train Loss: 0.0726, Val Loss: 0.0744, Accuracy: 97.62%
# Epoch [51], Train Loss: 0.0714, Val Loss: 0.0715, Accuracy: 97.79%
# Epoch [52], Train Loss: 0.0702, Val Loss: 0.0720, Accuracy: 97.69%
# Epoch [53], Train Loss: 0.0691, Val Loss: 0.0691, Accuracy: 97.86%
# Epoch [54], Train Loss: 0.0680, Val Loss: 0.0692, Accuracy: 97.79%
# Epoch [55], Train Loss: 0.0672, Val Loss: 0.0689, Accuracy: 97.81%
# Epoch [56], Train Loss: 0.0665, Val Loss: 0.0702, Accuracy: 97.81%
# Epoch [57], Train Loss: 0.0649, Val Loss: 0.0672, Accuracy: 97.81%
# Epoch [58], Train Loss: 0.0641, Val Loss: 0.0658, Accuracy: 97.98%
# Epoch [59], Train Loss: 0.0634, Val Loss: 0.0684, Accuracy: 97.76%
# Epoch [60], Train Loss: 0.0623, Val Loss: 0.0649, Accuracy: 97.90%
# Epoch [61], Train Loss: 0.0617, Val Loss: 0.0657, Accuracy: 97.88%
# Epoch [62], Train Loss: 0.0610, Val Loss: 0.0667, Accuracy: 97.88%
# Epoch [63], Train Loss: 0.0600, Val Loss: 0.0653, Accuracy: 98.02%
# Epoch [64], Train Loss: 0.0592, Val Loss: 0.0625, Accuracy: 98.02%
# Epoch [65], Train Loss: 0.0585, Val Loss: 0.0628, Accuracy: 98.00%
# Epoch [66], Train Loss: 0.0579, Val Loss: 0.0625, Accuracy: 98.00%
# Epoch [67], Train Loss: 0.0572, Val Loss: 0.0624, Accuracy: 98.02%
# Epoch [68], Train Loss: 0.0563, Val Loss: 0.0622, Accuracy: 97.90%
# Epoch [69], Train Loss: 0.0558, Val Loss: 0.0612, Accuracy: 97.83%
# Epoch [70], Train Loss: 0.0549, Val Loss: 0.0611, Accuracy: 98.00%
# Epoch [71], Train Loss: 0.0546, Val Loss: 0.0599, Accuracy: 98.02%
# Epoch [72], Train Loss: 0.0537, Val Loss: 0.0600, Accuracy: 98.05%
# Epoch [73], Train Loss: 0.0530, Val Loss: 0.0584, Accuracy: 98.05%
# Epoch [74], Train Loss: 0.0525, Val Loss: 0.0593, Accuracy: 98.07%
# Epoch [75], Train Loss: 0.0521, Val Loss: 0.0587, Accuracy: 98.14%
# Epoch [76], Train Loss: 0.0516, Val Loss: 0.0576, Accuracy: 98.05%
# Epoch [77], Train Loss: 0.0506, Val Loss: 0.0568, Accuracy: 98.14%
# Epoch [78], Train Loss: 0.0502, Val Loss: 0.0575, Accuracy: 98.12%
# Epoch [79], Train Loss: 0.0499, Val Loss: 0.0590, Accuracy: 98.21%
# Epoch [80], Train Loss: 0.0494, Val Loss: 0.0564, Accuracy: 98.05%
# Epoch [81], Train Loss: 0.0487, Val Loss: 0.0570, Accuracy: 98.26%
# Epoch [82], Train Loss: 0.0480, Val Loss: 0.0565, Accuracy: 98.12%
# Epoch [83], Train Loss: 0.0477, Val Loss: 0.0576, Accuracy: 98.07%
# Epoch [84], Train Loss: 0.0475, Val Loss: 0.0563, Accuracy: 98.12%
# Epoch [85], Train Loss: 0.0468, Val Loss: 0.0567, Accuracy: 98.10%
# Epoch [86], Train Loss: 0.0463, Val Loss: 0.0544, Accuracy: 98.21%
# Epoch [87], Train Loss: 0.0458, Val Loss: 0.0559, Accuracy: 98.21%
# Epoch [88], Train Loss: 0.0454, Val Loss: 0.0553, Accuracy: 98.19%
# Epoch [89], Train Loss: 0.0451, Val Loss: 0.0547, Accuracy: 98.29%
# Epoch [90], Train Loss: 0.0445, Val Loss: 0.0537, Accuracy: 98.26%
# Epoch [91], Train Loss: 0.0441, Val Loss: 0.0530, Accuracy: 98.19%
# Epoch [92], Train Loss: 0.0438, Val Loss: 0.0528, Accuracy: 98.33%
# Epoch [93], Train Loss: 0.0433, Val Loss: 0.0536, Accuracy: 98.24%
# Epoch [94], Train Loss: 0.0428, Val Loss: 0.0530, Accuracy: 98.21%
# Epoch [95], Train Loss: 0.0424, Val Loss: 0.0537, Accuracy: 98.31%
# Epoch [96], Train Loss: 0.0423, Val Loss: 0.0522, Accuracy: 98.29%
# Epoch [97], Train Loss: 0.0417, Val Loss: 0.0515, Accuracy: 98.29%
# Epoch [98], Train Loss: 0.0414, Val Loss: 0.0532, Accuracy: 98.31%
# Epoch [99], Train Loss: 0.0410, Val Loss: 0.0534, Accuracy: 98.24%
# Epoch [100], Train Loss: 0.0406, Val Loss: 0.0514, Accuracy: 98.40%

# %%
#test the model
print("Testing the model on test dataset...")  
my_model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        outputs = my_model(images)
        loss = ce_loss(outputs, labels)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print(f"Test Accuracy: {100 * correct / total:.3f}%")
print("Testing completed.")
#plot the target and predicted values
import matplotlib.pyplot as plt
def plot_predictions(images, labels, predictions):
    fig, axes = plt.subplots(1, 5, figsize=(15, 3))
    for i in range(5):
        ax = axes[i]
        ax.imshow(images[i].squeeze(), cmap='gray')
        ax.set_title(f"Label: {labels[i]}, Pred: {predictions[i]}")
        ax.axis('off')
    plt.show()
# Out:
# Testing the model on test dataset...
# Test Accuracy: 97.965%
# Testing completed.
